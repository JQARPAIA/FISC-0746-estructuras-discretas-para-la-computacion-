# %%
from collections import defaultdict, namedtuple, Counter, deque
import csv
import random
from urllib.request import urlretrieve

# %%
pelicula_data = 'https://raw.githubusercontent.com/skielosky/FISC-0746-estructura-discretas-computacion-2019/master/laboratorios/secuencias/peliculas_metadata.csv'
pelicula_csv = 'movies.csv'
urlretrieve(pelicula_data, pelicula_csv)
# Out:
# ('movies.csv', <http.client.HTTPMessage at 0x7f60358eb6a0>)

# %%
pelicula = namedtuple('Peliculas', 'title year score')

# %%
def obtener_peliculas_por_director(data=pelicula_csv):
    """Extracts all movies from csv and stores them in a dictionary
       where keys are directors, and values is a list of movies (named tuples)"""
    directors = defaultdict(list)
    with open(data, encoding='utf-8') as f:
        for line in csv.DictReader(f):
            try:
                director = line['director_name']
                movie = line['movie_title'].replace('\xa0', '')
                year = int(line['title_year'])
                score = float(line['imdb_score'])
            except ValueError:
                continue

            m = pelicula(title=movie, year=year, score=score)
            directors[director].append(m)

    return directors

# %%
directores = obtener_peliculas_por_director()

# %% [markdown]
# ## Tarea 01
# 1.	Por Director: Nombre, Año y Rating de la película con mejor Rating
# 2.	Por Director: promedio de rating
# 3.	Director con el mejor rating
# 4.	Lista de películas estrenadas en el 2016
# 5.	Mejor Película del 2016
# 6.	Director con el mejor rating en el 2016
# 7. Lista de peliculas con dos o mas directores

# %%
directores
# Out:
# defaultdict(list,
#             {'James Cameron': [Peliculas(title='Avatar', year=2009, score=7.9),
#               Peliculas(title='Titanic', year=1997, score=7.7),
#               Peliculas(title='Terminator 2: Judgment Day', year=1991, score=8.5),
#               Peliculas(title='True Lies', year=1994, score=7.2),
#               Peliculas(title='The Abyss', year=1989, score=7.6),
#               Peliculas(title='Aliens', year=1986, score=8.4),
#               Peliculas(title='The Terminator', year=1984, score=8.1)],
#              'Gore Verbinski': [Peliculas(title="Pirates of the Caribbean: At World's End", year=2007, score=7.1),
#               Peliculas(title="Pirates of the Caribbean: Dead Man's Chest", year=2006, score=7.3),
#               Peliculas(title='The Lone Ranger', year=2013, score=6.5),
#               Peliculas(title='Rango', year=2011, score=7.2),
#               Peliculas(title='Pirates of the Caribbean: The Curse of the Black Pearl', year=2003, score=8.1),
# ...

# %% [markdown]
# 1. Por Director: Nombre, Año y Rating de la película con mejor Rating

# %%
for name, movie in directores.items():
  may=0
  peli= " "
  for peliculas in movie:
    if may<peliculas[2]:
      may=peliculas[2]
      peli=peliculas[0]
  print("La pelicula con mejor rating es '"+str(peli)+"' con "+str(may)+" en el año "+str(peliculas[1])+" del director "+str(name)+".")
  print("\n")

# %% [markdown]
# 2. Por Director: promedio de rating

# %%
for name, movie in directores.items():
  sum = 0
  for peliculas in movie:
    sum = sum + peliculas[2]
  prom= sum/len(movie)
  print(f'{name} promedio del rating: {prom:.2f}.')
  print("\n")

# %% [markdown]
# 3. Director con el mejor rating

# %%
mayor=0
dtor= " "
for name, movie in directores.items():
  may=0
  for peliculas in movie:
    if may<peliculas[2]:
      may=peliculas[2]
  if mayor<may:
    mayor=may
    dtor=name
print("El director "+str(dtor)+" tiene el mejor rating con "+str(mayor)+".")

# %% [markdown]
# 4. Lista de películas estrenadas en el 2016

# %%
print("Las peliculas estrenadas en el año 2016 fueron: \n\n")
for name, movie in directores.items():
  for peliculas in movie:
    if peliculas[1]==2016:
      print(f'" {peliculas[0]} " | {name}')

# %% [markdown]
# 5. Mejor Película del 2016

# %%
may=0
mej=" "
for name, movie in directores.items():
  for peliculas in movie:
    if peliculas[1]==2016:
      if may<peliculas[2]:
        may=peliculas[2]
        mej=peliculas[0]
        nam=name
print(f'La mejor pelicula del año 2016 fue " {mej} " con rating {may} del director {nam}.')

# %% [markdown]
# 6. Director con el mejor rating en el 2016

# %%
nom = " "
may = 0

for name, movie in directores.items():
  for peliculas in movie:
    if peliculas[1]==2016:
      if may<peliculas[2]:
        may=peliculas[2]
        nom=name
print("El mejor directo del 2016 fue "+str(nom)+" con "+str(may)+".")

# %% [markdown]
# #Laboratorio 12

# %% [markdown]
# 7. Lista de peliculas con dos o mas directores

# %%
mej = " "

for name, movie in directores.items():
  for peliculas in movie:
    cont = 0
    mej=peliculas[0]
    for peliculas in movie:
      if peliculas[0]==mej:
        cont=cont+1
  if cont>=2:
      print(f' "{mej}" tiene {cont} directores.')

# %% [markdown]
# 8. Mostrar todas las peliculas entre el 2000 y el 2014 con un rating mayor a 7.0, por cada director

# %%
for name, movie in directores.items():
  print(f'{name}')
  for peliculas in movie:
    if peliculas[1]>=2000 and peliculas[1]<=2014:
      if peliculas[2]>=7.0:
        print(f'{peliculas[0]} | {peliculas[1]} | {peliculas[2]}')
  print(" ")
# Out:
# James Cameron
# Avatar | 2009 | 7.9
#
# Gore Verbinski
# Pirates of the Caribbean: At World's End | 2007 | 7.1
# Pirates of the Caribbean: Dead Man's Chest | 2006 | 7.3
# Rango | 2011 | 7.2
# Pirates of the Caribbean: The Curse of the Black Pearl | 2003 | 8.1
#
# Sam Mendes
# Skyfall | 2012 | 7.8
# Road to Perdition | 2002 | 7.7
# Jarhead | 2005 | 7.1
# Revolutionary Road | 2008 | 7.3
# Away We Go | 2009 | 7.1
# Skyfall | 2012 | 7.8
#
# Christopher Nolan
# The Dark Knight Rises | 2012 | 8.5
# The Dark Knight | 2008 | 9.0
# Interstellar | 2014 | 8.6
# Inception | 2010 | 8.8
# Batman Begins | 2005 | 8.3
# Insomnia | 2002 | 7.2
# The Prestige | 2006 | 8.5
# Memento | 2000 | 8.5
#
# Andrew Stanton
# WALL·E | 2008 | 8.4
# Finding Nemo | 2003 | 8.2
#
# Sam Raimi
# Spider-Man 2 | 2004 | 7.3
# Spider-Man | 2002 | 7.3
#
# Nathan Greno
# Tangled | 2010 | 7.8
#
# Joss Whedon
# The Avengers | 2012 | 8.1
# The Avengers | 2012 | 8.1
# Serenity | 2005 | 8.0
#
# David Yates
# ...
